# %%
import numpy as np
import numpy.random as rand
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# %%
x=np.arange(1,10)
y=2*x
plt.plot(x,y)

# %% [markdown]
# ## Add title and Labels

# %%
plt.plot(x,y)
plt.title('Line Plot')
plt.xlabel('X-Axis')
plt.ylabel('Y-Axis')
plt.show()

# %% [markdown]
# ## Changing line Aesthetics

# %%
plt.plot(x,y,color='red',linestyle='dotted',linewidth=2)
plt.show()

# %%
# Multiple Line graph
x=np.arange(1,11)
y1=2*x
y2=3*x
plt.plot(x,y1,label='y=2x',color='blue',linewidth=2)
plt.plot(x,y2,label='y=3x',color='green',linewidth=3)
plt.title('Multiple Lines')
plt.xlabel('X-Axis')
plt.ylabel('Y-Axis')
plt.grid(True)
plt.legend()
plt.show()

# %%
x=np.arange(0,11)
y1=2*x
y2=3*x
plt.subplot(1,2,1)
plt.title('Graph Subplot 1')
plt.plot(x,y1,label='y=2x',color='blue',linewidth=2)
plt.subplot(1,2,2)
plt.title('Graph Subplot 2')
plt.plot(x,y2,label='y=3x',color='green',linewidth=3)
plt.show()

# %% [markdown]
# ## Bar Plot

# %%
students={'John':25,'Alice':20,'Bob':18,'Diana':32}
names=list(students.keys())
ages=list(students.values())
plt.title('Bar Graph')
plt.xlabel('X-axis')
plt.ylabel('Y-axis')
plt.bar(names,ages,color='purple',width=0.3)
# plt.bar(names,ages,color=(0.5,0.9,0.7),width=0.3) # RGB color values
plt.show()

# %% [markdown]
# ## Horizontal Bar Plot

# %%
plt.barh(names,ages,color='orange')
plt.title('Horizontal Bar Chart')
plt.xlabel('Ages')
plt.ylabel('Names')
# plt.grid(True)
plt.show()

# %% [markdown]
# ## Scatter Plot

# %%
x=np.arange(0,20)
y=rand.randint(1,100,size=20)
plt.title('Scatter Plot')
plt.scatter(x,y,color='blue')
plt.show()

# %% [markdown]
# ## Changing Mark Aesthetics
# Supported Markers:
#         '.': 'point',
#         ',': 'pixel',
#         'o': 'circle',
#         'v': 'triangle_down',
#         '^': 'triangle_up',
#         '<': 'triangle_left',
#         '>': 'triangle_right',
#         '1': 'tri_down',
#         '2': 'tri_up',
#         '3': 'tri_left',
#         '4': 'tri_right',
#         '8': 'octagon',
#         's': 'square',
#         'p': 'pentagon',
#         '*': 'star',
#         'h': 'hexagon1',
#         'H': 'hexagon2',
#         '+': 'plus',
#         'x': 'x',
#         'D': 'diamond',
#         'd': 'thin_diamond',
#         '|': 'vline',
#         '_': 'hline',
#         'P': 'plus_filled',
#         'X': 'x_filled',
#         TICKLEFT: 'tickleft',
#         TICKRIGHT: 'tickright',
#         TICKUP: 'tickup',
#         TICKDOWN: 'tickdown',
#         CARETLEFT: 'caretleft',
#         CARETRIGHT: 'caretright',
#         CARETUP: 'caretup',
#         CARETDOWN: 'caretdown',
#         CARETLEFTBASE: 'caretleftbase',
#         CARETRIGHTBASE: 'caretrightbase',
#         CARETUPBASE: 'caretupbase',
#         CARETDOWNBASE: 'caretdownbase',
#         "None": 'nothing',
#         "none": 'nothing',
#         ' ': 'nothing',
#         '': 'nothing'

# %%
x=np.arange(0,20)
y=rand.randint(1,100,size=20)
plt.title('Scatter Plot')
plt.scatter(x,y,color='red',marker='4',s=100)

# %%
x=np.arange(0,10)
a1=rand.randint(1,100,size=10)
b1=rand.randint(1,100,size=10)
plt.title('Multiple Scatter Plots')
plt.scatter(x,a1,color='blue',label='Dataset A',marker='o',s=50)
plt.scatter(x,b1,color='red',label='Dataset B',marker='*',s=100)
plt.xlabel('X-axis')
plt.ylabel('Y-axis')
plt.legend()
plt.grid(True)
plt.show()

# %% [markdown]
# ## Scatter plot subplot

# %%
x=np.arange(0,10)
a1=rand.randint(1,100,size=10)
b1=rand.randint(1,100,size=10)
plt.subplot(1,2,1)
plt.scatter(x,a1,color='blue',label='Dataset A', marker='o',s=50)
plt.xlabel('X-axis')
plt.ylabel('Y-axis')
plt.legend()
plt.subplot(1,2,2)
plt.scatter(x,b1,color='red',label='Dataset B', marker='*',s=100)
plt.xlabel('X-axis')
plt.ylabel('Y-axis')
plt.legend()
plt.grid(True)
plt.show()

# %% [markdown]
# ## Histogram

# %%
data=rand.randn(1000)
plt.hist(data,bins=5,color='brown',edgecolor='black')
plt.title('Histogram')
plt.xlabel('Value')
plt.ylabel('Frequency')
plt.show()

# %% [markdown]
# ## Working with dataset

# %%
df=pd.read_excel('temp.xlsx',sheet_name='Sheet1')
df.columns=df.columns.str.strip()
df
# Out:
#         Date  City  Temperature
# 0 2025-01-01   CTC           44
# 1 2025-01-02   CTC           57
# 2 2025-01-03  BBSR           67
# 3 2025-01-04  BBSR           46
# 4 2025-01-05   RKL           46
# 5 2025-01-06   RKL           56
# 6 2025-01-07  BBSR           78
# 7 2025-01-08   CTC          100
# 8 2025-01-09    MB           35

# %%
plt.hist(df['Temperature'],bins=10,color='yellow',edgecolor='black')
plt.show()

# %% [markdown]
# ## Box Plot

# %%
one=rand.randint(1,100,size=10)
two=rand.randint(1,100,size=10)
three=rand.randint(1,100,size=10)
data=list([one,two,three])
plt.boxplot(data)
plt.show()

# %% [markdown]
# ## Violin Plot

# %%
plt.title('Violin Plot')
plt.violinplot([one,two,three],showmeans=True)
plt.show()

# %% [markdown]
# ## Pie Plot

# %%
fruits=['Apple','Banana','Cherry','Date']
quantities=[10,15,7,12]
plt.pie(quantities,labels=fruits)
plt.title('Pie Chart')
plt.show()

# %% [markdown]
# ## Doughnut Chart

# %%
plt.pie(quantities,labels=fruits,radius=3)
plt.title('Pie chart with Custom Radius')
plt.pie([1],colors='white',radius=1)
plt.show()

# %%
fmri=sns.load_dataset('fmri')
fmri.head(10)
# Out:
#   subject  timepoint event    region    signal
# 0     s13         18  stim  parietal -0.017552
# 1      s5         14  stim  parietal -0.080883
# 2     s12         18  stim  parietal -0.081033
# 3     s11         18  stim  parietal -0.046134
# 4     s10         18  stim  parietal -0.037970
# 5      s9         18  stim  parietal -0.103513
# 6      s8         18  stim  parietal -0.064408
# 7      s7         18  stim  parietal -0.060526
# 8      s6         18  stim  parietal -0.007029
# 9      s5         18  stim  parietal -0.040557

# %%
# hue is used to color the lines based on the 'region' column
# style is used to differentiate  the lines based on the 'event' column
sns.lineplot(data=fmri,x='timepoint',y='signal',style='event',hue='region')
plt.show()

# %%
# using markers and dashes
sns.lineplot(data=fmri,x='timepoint',y='signal',style='event',hue='region',markers=True,dashes=False)
plt.show()

# %%
sns.lineplot(data=fmri,x='timepoint',y='signal',style='event',hue='region',markers=True,dashes=True)
plt.show()

# %%
# generate a sample Pokemon dataset and save it as an Excel file
pokemon_data={
    'Name':['Bulbasaur','Charmander','Squirtle','Pikachu','Jigglypuff'],
    'Type':['Grass/Poison','Fire','Water','Electric','Normal/Fairy'],
    'HP':[45,39,44,35,115],
    'Attack':[49,52,48,55,45],
    'Defense':[49,43,65,40,20],
    'Speed':[45,65,43,90,20]
}
pokemon_df=pd.DataFrame(pokemon_data)
pokemon_df.to_excel('pokemon_dataset.xlsx',index=False)
pokemon_df.head()
# Out:
#          Name          Type   HP  Attack  Defense  Speed
# 0   Bulbasaur  Grass/Poison   45      49       49     45
# 1  Charmander          Fire   39      52       43     65
# 2    Squirtle         Water   44      48       65     43
# 3     Pikachu      Electric   35      55       40     90
# 4  Jigglypuff  Normal/Fairy  115      45       20     20

# %%
sns.scatterplot(data=pokemon_df,x='Attack',y='Defense',style='Type',hue='Type')
plt.show()

# %%
sns.set_style('whitegrid')
# palette='viridis' sets the color palette for the bars
# hue ='Type' colors the bars based on pokemon type
sns.barplot(data=pokemon_df,x='Name',y='HP',palette='viridis',hue='Type')
plt.title('Pokemon HP Comparison')
plt.xlabel='Pokemon'
plt.ylabel='HP'
plt.show()

# %%
iris=sns.load_dataset('iris')
iris.head()
# Out:
#    sepal_length  sepal_width  petal_length  petal_width species
# 0           5.1          3.5           1.4          0.2  setosa
# 1           4.9          3.0           1.4          0.2  setosa
# 2           4.7          3.2           1.3          0.2  setosa
# 3           4.6          3.1           1.5          0.2  setosa
# 4           5.0          3.6           1.4          0.2  setosa

# %%
sns.scatterplot(data=iris,x='sepal_length',y='sepal_width',hue='species',style='species')
plt.show()

# %%
diamond_data={
    'carat':[0.23,0.45,0.31,0.75,1.01],
    'cut':['Fair','Premium','Good','Very Good','Ideal'],
    'clarities':['I1','SI2','SI1','VS2','VS1']
}
diamond_df=pd.DataFrame(diamond_data)
diamond_df.head()
# Out:
#    carat        cut clarities
# 0   0.23       Fair        I1
# 1   0.45    Premium       SI2
# 2   0.31       Good       SI1
# 3   0.75  Very Good       VS2
# 4   1.01      Ideal       VS1

# %%
sns.histplot(diamond_df['carat'],kde=True,bins=10)
plt.title('Distribution of Diamond Carat')
plt.xlabel='Carat'
plt.ylabel='Density'
plt.show()

# %%
churn_data={
    'customer_id':[15634602,15634603,15634604,15634605,15634606],
    'gender':['Female','Male','Male','Male','Female'],
    'age':[42,41,42,39,43],
    'tenure':[3,1,8,1,2],
    'balance':[0.0,83807.86,159660.80,0.0,125510.80],
    'exited':[1,0,1,0,0]
}
df=pd.DataFrame(churn_data)
print(df)
# Out:
#    customer_id  gender  age  tenure    balance  exited
# 0     15634602  Female   42       3       0.00       1
# 1     15634603    Male   41       1   83807.86       0
# 2     15634604    Male   42       8  159660.80       1
# 3     15634605    Male   39       1       0.00       0
# 4     15634606  Female   43       2  125510.80       0
